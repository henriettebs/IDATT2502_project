# %%
import numpy as np
import time as tm
import datetime as dt
import tensorflow as tf
from yahoo_fin import stock_info as yf
from sklearn.preprocessing import MinMaxScaler
from collections import deque
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, Bidirectional
import matplotlib.pyplot as plt

# %%
from keras.layers import *
from keras.models import *
from keras import backend as K

class attention(Layer):
    def __init__(self, return_sequences=True):
        self.return_sequences = return_sequences
        super(attention,self).__init__()

    def build(self, input_shape):
        self.W=self.add_weight(name="att_weight", shape=(input_shape[-1],1),
                               initializer="normal")
        self.b=self.add_weight(name="att_bias", shape=(input_shape[1],1),
                               initializer="normal")
        super(attention,self).build(input_shape)


    def call(self, x):
        e = K.tanh(K.dot(x,self.W)+self.b)
        a = K.softmax(e, axis=1)
        output = x*a
        if self.return_sequences:
            return output
        return K.sum(output, axis=1)

# %%
N_STEPS = 7
LOOKUP_STEPS = [1]
STOCK = 'AMZN'

date_now = tm.strftime('%Y-%m-%d')
yesterday  = dt.date.today() - dt.timedelta(days=2)
date_3_years_back = (yesterday - dt.timedelta(days=1104)).strftime('%Y-%m-%d')

# %%
init_df = yf.get_data(
    STOCK, 
    start_date=date_3_years_back, 
    end_date=date_now, 
    interval='1d')

# %%
init_df = init_df.drop(['open', 'high', 'low', 'adjclose', 'ticker', 'volume'], axis=1)
init_df['date'] = init_df.index

# %%
data = init_df['close']
data = np.append(data,0.005)
today = str(tm.strftime('%Y-%m-%d'))
print(data)

plt.style.use(style='seaborn-whitegrid')
plt.figure(figsize=(16,10))
plt.plot(init_df['close'][-200:])
plt.xlabel("days")
plt.ylabel("price")
plt.legend([f'Actual price for {STOCK}'])
plt.show()
# Out:
# [9.02330017e+01 9.00855026e+01 8.97884979e+01 8.94100037e+01
#  8.92939987e+01 8.85824966e+01 8.89000015e+01 8.76555023e+01
#  8.77300034e+01 8.69745026e+01 8.76265030e+01 8.76395035e+01
#  8.72764969e+01 8.67354965e+01 8.72860031e+01 8.86920013e+01
#  8.98470001e+01 9.09254990e+01 9.00400009e+01 8.90800018e+01
#  8.84980011e+01 8.80345001e+01 8.70240021e+01 8.75800018e+01
#  8.74755020e+01 8.69605026e+01 8.74359970e+01 8.80165024e+01
#  8.80469971e+01 8.84605026e+01 8.95329971e+01 8.92014999e+01
#  8.96139984e+01 8.93249969e+01 8.96500015e+01 8.94605026e+01
#  9.34384995e+01 9.34899979e+01 9.23444977e+01 9.23919983e+01
#  9.49004974e+01 9.37484970e+01 9.51439972e+01 9.53430023e+01
#  9.45985031e+01 9.50524979e+01 9.41579971e+01 9.45650024e+01
#  9.34720001e+01 9.31009979e+01 9.38970032e+01 9.32360001e+01
#  9.45999985e+01 9.43730011e+01 9.42289963e+01 9.30820007e+01
#  9.14169998e+01 9.26624985e+01 9.29000015e+01 9.35339966e+01
#  1.00435997e+02 1.00209999e+02 1.02483498e+02 1.01993500e+02
#  1.02511497e+02 1.03963997e+02 1.06695503e+02 1.07540001e+02
#  1.08000000e+02 1.07493500e+02 1.06743500e+02 1.07783501e+02
#  1.08511002e+02 1.07654999e+02 1.04798500e+02 1.00464500e+02
#  9.86370010e+01 9.89794998e+01 9.42149963e+01 9.41875000e+01
#  9.76975021e+01 9.54495010e+01 9.87914963e+01 9.62014999e+01
#  9.50544968e+01 9.00305023e+01 9.45910034e+01 9.10429993e+01
#  8.38304977e+01 8.92500000e+01 8.44574966e+01 9.03919983e+01
#  9.15000000e+01 9.40465012e+01 9.23044968e+01 9.51415024e+01
#  9.70049973e+01 9.42919998e+01 9.77744980e+01 9.50049973e+01
#  9.81975021e+01 9.74860001e+01 9.53850021e+01 9.59414978e+01
#  9.53294983e+01 9.98795013e+01 1.00580002e+02 1.02150002e+02
#  1.02138000e+02 1.08443497e+02 1.14166000e+02 1.15384003e+02
#  1.20409500e+02 1.18750000e+02 1.19680496e+02 1.16405998e+02
#  1.18174500e+02 1.19972504e+02 1.20511002e+02 1.18800003e+02
#  1.15704002e+02 1.18635498e+02 1.23699997e+02 1.14302002e+02
#  1.15799500e+02 1.15889999e+02 1.17563004e+02 1.18380501e+02
#  1.18980499e+02 1.20449997e+02 1.17847504e+02 1.18396004e+02
#  1.19442497e+02 1.20488998e+02 1.21313004e+02 1.22466499e+02
#  1.24897003e+02 1.22336998e+02 1.21844002e+02 1.21093002e+02
#  1.20519501e+02 1.20055000e+02 1.22118500e+02 1.23552002e+02
#  1.23620499e+02 1.23919998e+02 1.23029999e+02 1.24150002e+02
#  1.26203003e+02 1.30042999e+02 1.32372498e+02 1.27898003e+02
#  1.27250999e+02 1.28634003e+02 1.30763504e+02 1.32048996e+02
#  1.32699005e+02 1.33750504e+02 1.35690994e+02 1.38220505e+02
#  1.36720001e+02 1.37729004e+02 1.34643494e+02 1.34018997e+02
#  1.37940994e+02 1.43934998e+02 1.44514999e+02 1.52852005e+02
#  1.50005997e+02 1.54055496e+02 1.59131500e+02 1.60000000e+02
#  1.55199997e+02 1.54199997e+02 1.50443497e+02 1.49994995e+02
#  1.48098495e+02 1.59841995e+02 1.56914505e+02 1.54995499e+02
#  1.49327499e+02 1.50445496e+02 1.52760498e+02 1.50016495e+02
#  1.51676498e+02 1.52593994e+02 1.58233994e+02 1.55594498e+02
#  1.56941498e+02 1.60251495e+02 1.61250000e+02 1.58373001e+02
#  1.57408005e+02 1.54033493e+02 1.58112000e+02 1.58050995e+02
#  1.57401001e+02 1.59120499e+02 1.65624496e+02 1.63024002e+02
#  1.64868500e+02 1.64235992e+02 1.65373001e+02 1.67324493e+02
#  1.72092499e+02 1.70000000e+02 1.70089996e+02 1.72548004e+02
#  1.74955994e+02 1.76572495e+02 1.68399994e+02 1.64731003e+02
#  1.57492004e+02 1.63430496e+02 1.58755493e+02 1.55811005e+02
#  1.55148499e+02 1.57806503e+02 1.53904999e+02 1.50436493e+02
#  1.47745499e+02 1.48023499e+02 1.56449493e+02 1.49992996e+02
#  1.50989502e+02 1.54756500e+02 1.58702499e+02 1.57244003e+02
#  1.57436493e+02 1.61063004e+02 1.56250000e+02 1.59960007e+02
#  1.54998001e+02 1.59784500e+02 1.59527496e+02 1.64332504e+02
#  1.72146500e+02 1.72181503e+02 1.68185501e+02 1.66932495e+02
#  1.63635498e+02 1.60360504e+02 1.60850494e+02 1.59246994e+02
#  1.58820007e+02 1.60220001e+02 1.60352005e+02 1.64316498e+02
#  1.58139008e+02 1.60550507e+02 1.51807495e+02 1.50223999e+02
#  1.52420502e+02 1.62057999e+02 1.66100006e+02 1.65568497e+02
#  1.57186996e+02 1.51751007e+02 1.56869507e+02 1.55514008e+02
#  1.56440506e+02 1.56552994e+02 1.56783005e+02 1.55272995e+02
#  1.55850998e+02 1.54970001e+02 1.54919495e+02 1.55903000e+02
#  1.59253494e+02 1.59766998e+02 1.58401993e+02 1.61003998e+02
#  1.60176498e+02 1.59336502e+02 1.58128998e+02 1.57899994e+02
#  1.58864502e+02 1.55210007e+02 1.55074493e+02 1.55820999e+02
#  1.57848495e+02 1.58255997e+02 1.62048004e+02 1.61804001e+02
#  1.60082504e+02 1.60309006e+02 1.60326004e+02 1.59263504e+02
#  1.58634506e+02 1.64197998e+02 1.66100006e+02 1.64292496e+02
#  1.62846497e+02 1.59331497e+02 1.60925507e+02 1.56919006e+02
#  1.58108002e+02 1.59134995e+02 1.55710495e+02 1.56041504e+02
#  1.58294495e+02 1.56373505e+02 1.55212494e+02 1.56037994e+02
#  1.63169006e+02 1.65349503e+02 1.64611496e+02 1.64699997e+02
#  1.66306503e+02 1.61628998e+02 1.61880997e+02 1.60309998e+02
#  1.67143997e+02 1.69000000e+02 1.65626495e+02 1.66550003e+02
#  1.67607498e+02 1.66147003e+02 1.65250000e+02 1.64328995e+02
#  1.63106506e+02 1.63885498e+02 1.63447495e+02 1.65432007e+02
#  1.66411499e+02 1.62494995e+02 1.59037003e+02 1.59725006e+02
#  1.57976501e+02 1.52858002e+02 1.54646500e+02 1.57307007e+02
#  1.54726501e+02 1.50250000e+02 1.48878494e+02 1.50022995e+02
#  1.47597504e+02 1.53142502e+02 1.52882004e+02 1.55679504e+02
#  1.54474503e+02 1.54084000e+02 1.54593002e+02 1.56786499e+02
#  1.51399506e+02 1.53748001e+02 1.55543503e+02 1.56875000e+02
#  1.54353500e+02 1.52313004e+02 1.52601501e+02 1.53786499e+02
#  1.52764496e+02 1.54703995e+02 1.58050003e+02 1.61336502e+02
#  1.61190994e+02 1.63969498e+02 1.64964996e+02 1.68610001e+02
#  1.68969498e+02 1.70000000e+02 1.66649994e+02 1.68954498e+02
#  1.69972000e+02 1.68600494e+02 1.66734497e+02 1.68100998e+02
#  1.65451996e+02 1.67044006e+02 1.70449997e+02 1.70871506e+02
#  1.72925003e+02 1.73565506e+02 1.73371002e+02 1.69324493e+02
#  1.65593506e+02 1.63526993e+02 1.65318497e+02 1.64580505e+02
#  1.59524506e+02 1.61195496e+02 1.57597000e+02 1.58073502e+02
#  1.61145004e+02 1.63519501e+02 1.61613998e+02 1.61589996e+02
#  1.62384003e+02 1.60154007e+02 1.62249496e+02 1.62952499e+02
#  1.63257996e+02 1.61505493e+02 1.61153503e+02 1.60932495e+02
#  1.61699493e+02 1.59350494e+02 1.60311005e+02 1.59900497e+02
#  1.63205505e+02 1.64057495e+02 1.67482498e+02 1.67341507e+02
#  1.69193497e+02 1.69156494e+02 1.70762497e+02 1.74462006e+02
#  1.74345001e+02 1.72697998e+02 1.75272003e+02 1.75190994e+02
#  1.72453995e+02 1.70072998e+02 1.72194504e+02 1.72406998e+02
#  1.72007996e+02 1.71648499e+02 1.75548996e+02 1.83787003e+02
#  1.84828995e+02 1.86570496e+02 1.85966995e+02 1.85927505e+02
#  1.83867996e+02 1.84084000e+02 1.81559998e+02 1.78681503e+02
#  1.77479507e+02 1.78659500e+02 1.79259995e+02 1.81901505e+02
#  1.82832001e+02 1.84990997e+02 1.81319504e+02 1.81516006e+02
#  1.79996002e+02 1.66379501e+02 1.66574005e+02 1.68311996e+02
#  1.67735992e+02 1.68799500e+02 1.67246994e+02 1.67093506e+02
#  1.66033997e+02 1.64605499e+02 1.65175003e+02 1.64698502e+02
#  1.64949493e+02 1.62098007e+02 1.60061005e+02 1.59387497e+02
#  1.59997498e+02 1.63293503e+02 1.65289001e+02 1.64959000e+02
#  1.65800003e+02 1.67481506e+02 1.71078506e+02 1.73539505e+02
#  1.73949997e+02 1.73156006e+02 1.73902496e+02 1.75464493e+02
#  1.76274994e+02 1.74207993e+02 1.73457504e+02 1.72858505e+02
#  1.72500000e+02 1.73789505e+02 1.74412003e+02 1.73126007e+02
#  1.67786499e+02 1.67181503e+02 1.69002502e+02 1.70800003e+02
#  1.71276001e+02 1.70289993e+02 1.65798004e+02 1.65056000e+02
#  1.64251999e+02 1.64162994e+02 1.59488998e+02 1.61050003e+02
#  1.63100494e+02 1.65121506e+02 1.64431000e+02 1.62315002e+02
#  1.62366501e+02 1.64214005e+02 1.64992996e+02 1.70451004e+02
#  1.72337006e+02 1.72207504e+02 1.70753006e+02 1.71750504e+02
#  1.66777496e+02 1.66018494e+02 1.68803497e+02 1.69624496e+02
#  1.72328506e+02 1.68621506e+02 1.65905502e+02 1.65637497e+02
#  1.69199997e+02 1.73850006e+02 1.75949493e+02 1.74449005e+02
#  1.78811493e+02 1.74102493e+02 1.73625000e+02 1.76257507e+02
#  1.77283997e+02 1.77035004e+02 1.77449997e+02 1.84802994e+02
#  1.83828506e+02 1.78628494e+02 1.79001999e+02 1.79020493e+02
#  1.75227997e+02 1.78078506e+02 1.75353500e+02 1.72186005e+02
#  1.71867996e+02 1.69489502e+02 1.71368500e+02 1.76164505e+02
#  1.76158005e+02 1.74171005e+02 1.72212006e+02 1.69567505e+02
#  1.69091507e+02 1.73315002e+02 1.68871002e+02 1.70017502e+02
#  1.67078995e+02 1.70417007e+02 1.71037003e+02 1.71068497e+02
#  1.69669495e+02 1.70660995e+02 1.69201004e+02 1.68644501e+02
#  1.66716995e+02 1.70404495e+02 1.67522003e+02 1.64356995e+02
#  1.63253998e+02 1.62554001e+02 1.61485992e+02 1.65362000e+02
#  1.65207001e+02 1.61214005e+02 1.62138000e+02 1.58917496e+02
#  1.56298996e+02 1.51667496e+02 1.42643005e+02 1.44544006e+02
#  1.39985992e+02 1.38872498e+02 1.39637497e+02 1.43977997e+02
#  1.49573502e+02 1.51193497e+02 1.50612503e+02 1.38845505e+02
#  1.57639496e+02 1.57935501e+02 1.61413498e+02 1.61189499e+02
#  1.59003494e+02 1.53293503e+02 1.55167007e+02 1.56510498e+02
#  1.58100494e+02 1.54652496e+02 1.52601501e+02 1.50197495e+02
#  1.44826996e+02 1.51358002e+02 1.53788498e+02 1.53563004e+02
#  1.51141998e+02 1.52052505e+02 1.47898499e+02 1.45641006e+02
#  1.37453003e+02 1.36014496e+02 1.39279007e+02 1.46817505e+02
#  1.45524506e+02 1.41852997e+02 1.47366501e+02 1.53104004e+02
#  1.57238998e+02 1.61250504e+02 1.61491501e+02 1.64889008e+02
#  1.63408005e+02 1.63649506e+02 1.64773499e+02 1.68990494e+02
#  1.69315002e+02 1.66300995e+02 1.62997498e+02 1.63559998e+02
#  1.68346497e+02 1.64054993e+02 1.58755997e+02 1.57784500e+02
#  1.54460495e+02 1.51121994e+02 1.50787506e+02 1.55541000e+02
#  1.51706497e+02 1.52785004e+02 1.58115494e+02 1.53998001e+02
#  1.48296005e+02 1.44350006e+02 1.46074005e+02 1.39391006e+02
#  1.38167007e+02 1.44596497e+02 1.24281502e+02 1.24500000e+02
#  1.24253502e+02 1.25928497e+02 1.16406998e+02 1.14772499e+02
#  1.08789001e+02 1.08859001e+02 1.05372002e+02 1.06930496e+02
#  1.13055000e+02 1.10810501e+02 1.15368500e+02 1.07112503e+02
#  1.07319000e+02 1.07591003e+02 1.07556999e+02 1.04099998e+02
#  1.06775002e+02 1.11077499e+02 1.15146500e+02 1.20209503e+02
#  1.21683998e+02 1.25511002e+02 1.22349998e+02 1.24790001e+02
#  1.23000000e+02 1.21180000e+02 1.16150002e+02 1.09650002e+02
#  1.03669998e+02 1.02309998e+02 1.07669998e+02 1.03660004e+02
#  1.06220001e+02 1.08680000e+02 1.08949997e+02 1.12440002e+02
#  1.16459999e+02 1.13220001e+02 1.07400002e+02 1.08919998e+02
#  1.06209999e+02 1.09559998e+02 1.13500000e+02 1.14330002e+02
#  1.16330002e+02 1.15540001e+02 1.11750000e+02 1.09220001e+02
#  1.10400002e+02 1.10629997e+02 1.13550003e+02 1.13760002e+02
#  1.18209999e+02 1.22769997e+02 1.24629997e+02 1.22419998e+02
#  1.21139999e+02 1.14809998e+02 1.20970001e+02 1.22279999e+02
#  1.34949997e+02 1.35389999e+02 1.34160004e+02 1.39520004e+02
#  1.42570007e+02 1.40800003e+02 1.39410004e+02 1.37830002e+02
#  1.42690002e+02 1.40639999e+02 1.43550003e+02 1.43179993e+02
#  1.44779999e+02 1.42100006e+02 1.42300003e+02 1.38229996e+02
#  1.33220001e+02 1.33619995e+02 1.33800003e+02 1.37279999e+02
#  1.30750000e+02 1.29789993e+02 1.28729996e+02 1.26769997e+02
#  1.27820000e+02 1.27510002e+02 1.26110001e+02 1.29479996e+02
#  1.29820007e+02 1.33270004e+02 1.36449997e+02 1.26820000e+02
#  1.28550003e+02 1.26279999e+02 1.23529999e+02 1.24660004e+02
#  1.22190002e+02 1.18540001e+02 1.17309998e+02 1.13779999e+02
#  1.15150002e+02 1.14410004e+02 1.18010002e+02 1.14800003e+02
#  1.13000000e+02 1.15879997e+02 1.21089996e+02 1.20949997e+02
#  1.20300003e+02 1.14559998e+02 1.13669998e+02 1.12209999e+02
#  1.12900002e+02 1.12529999e+02 1.06900002e+02 1.13790001e+02
#  1.16360001e+02 1.15070000e+02 1.15250000e+02 1.19320000e+02
#  1.19820000e+02 1.20599998e+02 1.15660004e+02 1.10959999e+02
#  1.03410004e+02 1.02440002e+02 9.67900009e+01 9.21200027e+01
#  8.93000031e+01 9.09800034e+01 9.05299988e+01 8.99800034e+01
#  8.61399994e+01 9.66299973e+01 1.00790001e+02 5.00000000e-03]
# C:\Users\hanna\AppData\Local\Temp\ipykernel_8296\1930902855.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(style='seaborn-whitegrid')

# %%
scaler = MinMaxScaler()
init_df['close'] = scaler.fit_transform(np.expand_dims(init_df['close'].values, axis=1))

# %%
def GetTrainedModel(x_train, y_train):
  model = Sequential()
  model.add(LSTM(60, return_sequences=True, input_shape=(N_STEPS, len(['close']))))
  model.add(attention(return_sequences=True))
  model.add(Dropout(0.5))
  model.add(LSTM(120, return_sequences=False))
  model.add(Dropout(0.5))
  model.add(Dense(20))
  model.add(Dense(1))

  # model2 = Sequential()
  # model2.add(Embedding(n_unique_words, 128, input_length=maxlen))
  # model2.add(Bidirectional(LSTM(64, return_sequences=True)))
  # model2.add(attention(return_sequences=True)) # receive 3D and output 3D
  # model2.add(Dropout(0.5))
  # model2.add(Dense(1, activation='sigmoid'))
  # model2.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy']) 
  # model2.summary()


  BATCH_SIZE = 8
  EPOCHS = 100

  model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])
  model.summary()

  model.fit(x_train, y_train,
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            verbose=1)

  model.summary()

  return model

# %%
def PrepareData():
  df = init_df.copy()
  df['future'] = df['close']
  last_sequence = np.array(df['close'][-7:])
  df.dropna(inplace=True)
  sequence_data = []
  sequences = deque(maxlen=N_STEPS)

  for entry, target in zip(df[['close'] + ['date']].values, df['future'].values):
      sequences.append(entry)
      if len(sequences) == N_STEPS:
          sequence_data.append([np.array(sequences), target])

  last_sequence = list([s[:len(['close'])] for s in sequences]) + list(last_sequence)
  last_sequence = np.array(last_sequence).astype(np.float32)

  # construct the X's and Y's
  X, Y = [], []
  for seq, target in sequence_data:
      X.append(seq)
      Y.append(target)

  # convert to numpy arrays
  X = np.array(X)
  Y = np.array(Y)

  return df, last_sequence, X, Y

# %%
predictions = []
print("started")
df, last_sequence, x_train, y_train = PrepareData()
x_train = x_train[:, :, :len(['close'])].astype(np.float32)
model = GetTrainedModel(x_train, y_train)
# print(last_sequence)
last_sequence = last_sequence[-N_STEPS:]
# print(last_sequence)
last_sequence = np.expand_dims(last_sequence, axis=0)
prediction = model.predict(last_sequence)
print(f"Prediction{prediction}")
predicted_price = scaler.inverse_transform(prediction)[0][0]
print(predicted_price)

predictions.append(round(float(predicted_price), 2))
print(predictions)
# Out:
# started
# C:\Users\hanna\AppData\Local\Temp\ipykernel_8296\3779544858.py:15: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   last_sequence = np.array(last_sequence).astype(np.float32)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 60)             14880
#
#  attention (attention)       (None, 7, 60)             67
#
#  dropout (Dropout)           (None, 7, 60)             0
#
#  lstm_1 (LSTM)               (None, 120)               86880
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 20)                2420
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 104,268
# Trainable params: 104,268
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 95/95 [==============================] - 10s 13ms/step - loss: 0.0503 - accuracy: 0.0013
# Epoch 2/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0084 - accuracy: 0.0026
# Epoch 3/100
# 95/95 [==============================] - 1s 13ms/step - loss: 0.0076 - accuracy: 0.0026
# Epoch 4/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0076 - accuracy: 0.0026
# Epoch 5/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0073 - accuracy: 0.0026
# Epoch 6/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0057 - accuracy: 0.0026
# Epoch 7/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0054 - accuracy: 0.0026
# Epoch 8/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0054 - accuracy: 0.0026
# Epoch 9/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0054 - accuracy: 0.0026
# Epoch 10/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0048 - accuracy: 0.0026
# Epoch 11/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0.0039 - accuracy: 0.0026
# Epoch 12/100
# 95/95 [==============================] - 2s 18ms/step - loss: 0.0038 - accuracy: 0.0026
# Epoch 13/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0038 - accuracy: 0.0026
# Epoch 14/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0040 - accuracy: 0.0026
# Epoch 15/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0033 - accuracy: 0.0026
# Epoch 16/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0034 - accuracy: 0.0026
# Epoch 17/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0033 - accuracy: 0.0026
# Epoch 18/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0035 - accuracy: 0.0026
# Epoch 19/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0033 - accuracy: 0.0026
# Epoch 20/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0031 - accuracy: 0.0026
# Epoch 21/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0033 - accuracy: 0.0026
# Epoch 22/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0026 - accuracy: 0.0026
# Epoch 23/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0027 - accuracy: 0.0026
# Epoch 24/100
# 95/95 [==============================] - 1s 14ms/step - loss: 0.0025 - accuracy: 0.0026
# Epoch 25/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0024 - accuracy: 0.0026
# Epoch 26/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0027 - accuracy: 0.0026
# Epoch 27/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0027 - accuracy: 0.0026
# Epoch 28/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 0.0026
# Epoch 29/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0027 - accuracy: 0.0026
# Epoch 30/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0024 - accuracy: 0.0026
# Epoch 31/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0024 - accuracy: 0.0026
# Epoch 32/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0026 - accuracy: 0.0026
# Epoch 33/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 0.0026
# Epoch 34/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0025 - accuracy: 0.0026
# Epoch 35/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 36/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0022 - accuracy: 0.0026
# Epoch 37/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0024 - accuracy: 0.0026
# Epoch 38/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 39/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 40/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 41/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0025 - accuracy: 0.0026
# Epoch 42/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 0.0026
# Epoch 43/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 44/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 45/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 46/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0022 - accuracy: 0.0026
# Epoch 47/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0025 - accuracy: 0.0026
# Epoch 48/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0022 - accuracy: 0.0026
# Epoch 49/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 50/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 51/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 52/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0020 - accuracy: 0.0026
# Epoch 53/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 54/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 55/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 56/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0016 - accuracy: 0.0026
# Epoch 57/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 58/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0020 - accuracy: 0.0026
# Epoch 59/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 60/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 61/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0023 - accuracy: 0.0026
# Epoch 62/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 63/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 64/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 65/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 66/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 67/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 68/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 69/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 70/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0020 - accuracy: 0.0026
# Epoch 71/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 72/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 73/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0016 - accuracy: 0.0026
# Epoch 74/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 75/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 76/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 77/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 78/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0015 - accuracy: 0.0026
# Epoch 79/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 80/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 81/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0016 - accuracy: 0.0026
# Epoch 82/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 83/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0021 - accuracy: 0.0026
# Epoch 84/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 85/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 86/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0015 - accuracy: 0.0026
# Epoch 87/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 88/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0015 - accuracy: 0.0026
# Epoch 89/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 90/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0016 - accuracy: 0.0026
# Epoch 91/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 92/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0019 - accuracy: 0.0026
# Epoch 93/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 94/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 95/100
# 95/95 [==============================] - 1s 15ms/step - loss: 0.0015 - accuracy: 0.0026
# Epoch 96/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0018 - accuracy: 0.0026
# Epoch 97/100
# 95/95 [==============================] - 2s 17ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 98/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Epoch 99/100
# 95/95 [==============================] - 1s 16ms/step - loss: 0.0015 - accuracy: 0.0026
# Epoch 100/100
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0017 - accuracy: 0.0026
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 7, 60)             14880
#
#  attention (attention)       (None, 7, 60)             67
#
#  dropout (Dropout)           (None, 7, 60)             0
#
#  lstm_1 (LSTM)               (None, 120)               86880
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  dense (Dense)               (None, 20)                2420
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 104,268
# Trainable params: 104,268
# Non-trainable params: 0
# _________________________________________________________________
# 1/1 [==============================] - 2s 2s/step
# Prediction[[0.16823256]]
# 101.11471
# [101.11]

# %%
scaler.inverse_transform(model.predict(last_sequence))[0][0]

# numbers = []
# for x in range(1):
#     numbers.append(program())
# print(numbers.sum/len(numbers))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# 101.11471
